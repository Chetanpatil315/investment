# %%
# open and read the txt file.
text_file = open("C:\Users\chetan patil\Desktop\DataAnalysis\companies.txt", "r")

# Read each line of text file and save it in lines. 
lines = text_file.readlines()

# print lines
print(len(lines))
text_file.close()
# Out:
#   File "<ipython-input-6-ae3343c1c72b>", line 3
#     text_file = open("C:\Users\chetan patil\Desktop\DataAnalysis\companies.txt", "r")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
writer = csv.writer(outfile)
     writer.writerows(lines)
# Out:
#   File "<ipython-input-7-f3b6eb530cd2>", line 2
#     writer.writerows(lines)
#     ^
# IndentationError: unexpected indent

# %%
input_file = open(r"C:\Users\chetan patil\Desktop\DataAnalysis\companies.txt",encoding="Latin-1")
output_file = open(r'companies.csv', 'w',encoding="utf-8")

reader = csv.reader(input_file, delimiter='\t',quoting=csv.QUOTE_NONE)
writer = csv.writer(output_file)

for row in reader:
    writer.writerow(row)

input_file.close()
output_file.close()

# %%
import pandas as pd 
 
data = pd.read_csv("companies.csv") 
 
data
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# 12                           /Organization/1-800-Dentist
# 13                           /Organization/1-800-Doctors
# 14              /Organization/1-800-Publicrelations-Inc-
# ...

# %%
data['permalink'].unique()
# Out:
# array(['/Organization/-Fame', '/Organization/-Qounter',
#        '/Organization/-The-One-Of-Them-Inc-', ...,
#        '/Organization/Ã\x81Eron', '/Organization/Ã\x94Asys-2',
#        '/Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-Hizmetleri-Tic'],
#       dtype=object)

# %%
data['permalink'].unique().tolist()
# Out:
# ['/Organization/-Fame',
#  '/Organization/-Qounter',
#  '/Organization/-The-One-Of-Them-Inc-',
#  '/Organization/0-6-Com',
#  '/Organization/004-Technologies',
#  '/Organization/01Games-Technology',
#  '/Organization/0Ndine-Biomedical-Inc',
#  '/Organization/0Xdata',
#  '/Organization/1',
#  '/Organization/1-2-3-Listo',
#  '/Organization/1-4-All',
#  '/Organization/1-618-Technology',
#  '/Organization/1-800-Dentist',
#  '/Organization/1-800-Doctors',
#  '/Organization/1-800-Publicrelations-Inc-',
#  '/Organization/1-Mainstream',
#  '/Organization/1-Of-99',
#  '/Organization/10-20-Media',
#  '/Organization/10-Minutes-With',
#  '/Organization/1000-Corks',
#  '/Organization/1000-Markets',
#  '/Organization/1000Chi',
#  '/Organization/1000Lookz',
#  '/Organization/1000Memories',
#  '/Organization/1000Museums-Com',
#  '/Organization/1001-Menus',
#  '/Organization/1001Pharmacies-Com',
#  '/Organization/1006-Tv',
#  '/Organization/100Du-Tv',
#  '/Organization/100E-Com',
# ...

# %%
len(data['permalink'].unique().tolist())
# Out:
# 66368

# %%
data['permalink'].nunique()
# Out:
# 66368

# %%
import pandas as pd 
 
data2 = pd.read_csv(r"C:\Users\chetan patil\Desktop\DataAnalysis\rounds2.csv",encoding="Latin-1") 
 
data2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# 5                          /ORGANIZATION/004-TECHNOLOGIES
# 6                        /organization/01games-technology
# 7                     /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /ORGANIZATION/0XDATA
# 10                                   /organization/0xdata
# 11                                   /ORGANIZATION/0XDATA
# 12                                   /organization/0xdata
# 13                                        /ORGANIZATION/1
# 14                                        /organization/1
# ...

# %%
data2['company_permalink'].nunique()
# Out:
# 90247

# %%
len(data2['company_permalink'].unique().tolist())
# Out:
# 90247

# %%
master_frame=data.combine_first(data2)

# %%
master_frame
# Out:
#                                             category_list               city  \
# 0                                                   Media             Mumbai
# 1       Application Platforms|Real Time|Social Network...      Delaware City
# 2                                       Apps|Games|Mobile                NaN
# 3                                             Curated Web            Beijing
# 4                                                Software          Champaign
# 5                                                   Games          Hong Kong
# 6                                           Biotechnology          Vancouver
# 7                                               Analytics      Mountain View
# 8                                                  Mobile      San Francisco
# 9                                              E-Commerce         Las Condes
# 10                           Entertainment|Games|Software  Connellys Springs
# ...

# %%
master_frame.count()
# Out:
# category_list               63220
# city                        58340
# company_permalink          114949
# country_code                59410
# founded_at                  51147
# funded_at                  114949
# funding_round_code          31140
# funding_round_permalink    114949
# funding_round_type         114949
# homepage_url                61310
# name                        66367
# permalink                   66368
# raised_amount_usd           94959
# region                      58338
# state_code                  57821
# status                      66368
# dtype: int64

# %%
len(master_frame)
# Out:
# 114949
